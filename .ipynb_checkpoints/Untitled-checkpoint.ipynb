# %%
import pandas as pd
df = pd.read_excel("Book1.xlsx")
print(df.head())
# Out:
#   Table 1a: Number and percentage of finalised charges, by offence type (ANZSOC division), 1980/1981 - 2024/2025  \
# 0  For more information on how to interpret these...
# 1                              Back to contents page
# 2                                                NaN
# 3                     Offence type (ANZSOC division)
# 4                                       01: Homicide
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3  1980/1981  1981/1982  1982/1983  1983/1984  1984/1985  1985/1986
# 4        353        366        329        407        406        447
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 36 Unnamed: 37 Unnamed: 38  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# ...

# %%
df.head()
# Out:
#   Table 1a: Number and percentage of finalised charges, by offence type (ANZSOC division), 1980/1981 - 2024/2025  \
# 0  For more information on how to interpret these...
# 1                              Back to contents page
# 2                                                NaN
# 3                     Offence type (ANZSOC division)
# 4                                       01: Homicide
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3  1980/1981  1981/1982  1982/1983  1983/1984  1984/1985  1985/1986
# 4        353        366        329        407        406        447
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 36 Unnamed: 37 Unnamed: 38  \
# 0        NaN        NaN        NaN  ...         NaN         NaN         NaN
# ...
