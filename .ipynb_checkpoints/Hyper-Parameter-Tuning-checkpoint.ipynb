# %% [markdown]
# # Hyperparameter tuning Total Moodel

# %% [markdown]
# # Tuning a Random Forest Regression Model

# %% [markdown]
# Custom built expanding window validation functions will be used

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Import your helper functions
from timeseries_model_utils import (
    expanding_window_splits,
    run_expanding_cv,
    expanding_window_grid_search
)

from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_absolute_error

# %%
df = pd.read_csv("New_csv.csv")   # replace with your file
df = df.sort_values("Year").reset_index(drop=True)
df.head()
# Out:
#    Unnamed: 0  Year  Homicide  Assault  Sexual offences  \
# 0           0  1980       353     7208             1401
# 1           1  1981       366     7933             1092
# 2           2  1982       329     7760             1298
# 3           3  1983       407     8741             1449
# 4           4  1984       406     9349             1682
#
#    Harm or endanger persons  Robbery, blackmail, and extortion  Burglary   \
# 0                      2176                                426      11893
# 1                      2299                                494      12974
# 2                      2231                                504      14387
# 3                      2693                                657      13851
# 4                      2651                                729      13905
#
#    Theft  Fraud and related offences  ...  Traffic and vehicle offences  \
# 0  29103                       19794  ...                        173948
# 1  29654                       25007  ...                        142990
# 2  32682                       26131  ...                        104739
# 3  32304                       28481  ...                        105649
# 4  33492                       28069  ...                        116414
#
#    Offences against justice procedures and orders  \
# 0                                           27664
# 1                                           17981
# 2                                           13957
# 3                                           15332
# 4                                           16389
#
#    Offences against government  Environmental offences  \
# 0                         1376                    3521
# 1                         2027                    3360
# 2                         1203                    4025
# 3                          736                    2252
# 4                         1300                    2235
#
#    Miscellaneous offences   Total  Population  Crime_Index  Total_Lagged  \
# 0                    9651  331751     3112900    10.657297      331751.0
# 1                    9836  294409     3124900     9.421389      331751.0
# 2                    7878  252119     3156100     7.988308      294409.0
# 3                    7774  254658     3199300     7.959804      252119.0
# 4                    8552  274022     3227100     8.491277      254658.0
#
#    Population_lagged
# 0          3112900.0
# 1          3112900.0
# 2          3124900.0
# 3          3156100.0
# 4          3199300.0
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 24 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Unnamed: 0                                      45 non-null     int64
#  1   Year                                            45 non-null     int64
#  2   Homicide                                        45 non-null     int64
#  3   Assault                                         45 non-null     int64
#  4   Sexual offences                                 45 non-null     int64
#  5   Harm or endanger persons                        45 non-null     int64
#  6   Robbery, blackmail, and extortion               45 non-null     int64
#  7   Burglary                                        45 non-null     int64
#  8   Theft                                           45 non-null     int64
#  9   Fraud and related offences                      45 non-null     int64
#  10  Drug offences                                   45 non-null     int64
#  11  Weapons and explosives offences                 45 non-null     int64
#  12  Property damage                                 45 non-null     int64
#  13  Public order, health, and safety offences       45 non-null     int64
#  14  Traffic and vehicle offences                    45 non-null     int64
#  15  Offences against justice procedures and orders  45 non-null     int64
#  16  Offences against government                     45 non-null     int64
#  17  Environmental offences                          45 non-null     int64
#  18  Miscellaneous offences                          45 non-null     int64
#  19  Total                                           45 non-null     int64
#  20  Population                                      45 non-null     int64
#  21  Crime_Index                                     45 non-null     float64
#  22  Total_Lagged                                    45 non-null     float64
#  23  Population_lagged                               45 non-null     float64
# dtypes: float64(3), int64(21)
# memory usage: 8.6 KB

# %%
target_col = "Total"        # or any column you want to predict
feature_cols = ["Total_Lagged","Year","Population_lagged"]

X = df[feature_cols]
y = df[target_col]

# %%
param_grid = {
    "n_estimators": [100, 200, 400],
    "max_depth": [3, 5, None]
}

best_params, best_score, results_df = expanding_window_grid_search(
    RandomForestRegressor,
    param_grid,
    X, y,
    initial_train_size=10,
    horizon=1,
    step=1
)

print("\nBest Parameters:", best_params)
print("Best Score:", best_score)

results_df
# Out:
# [GridSearch] Params {'n_estimators': 100, 'max_depth': 3} → Score = 16010.3466
# [GridSearch] Params {'n_estimators': 100, 'max_depth': 5} → Score = 16444.2499
# [GridSearch] Params {'n_estimators': 100, 'max_depth': None} → Score = 16733.7300
# [GridSearch] Params {'n_estimators': 200, 'max_depth': 3} → Score = 16185.0096
# [GridSearch] Params {'n_estimators': 200, 'max_depth': 5} → Score = 15915.7255
# [GridSearch] Params {'n_estimators': 200, 'max_depth': None} → Score = 16120.6621
# [GridSearch] Params {'n_estimators': 400, 'max_depth': 3} → Score = 16093.0373
# [GridSearch] Params {'n_estimators': 400, 'max_depth': 5} → Score = 16142.8219
# [GridSearch] Params {'n_estimators': 400, 'max_depth': None} → Score = 16473.8126
#
# Best Parameters: {'n_estimators': np.float64(200.0), 'max_depth': np.float64(5.0)}
# Best Score: 15915.725465654978
#    n_estimators  max_depth         score
# 0           100        3.0  16010.346550
# 1           100        5.0  16444.249890
# 2           100        NaN  16733.730000
# 3           200        3.0  16185.009575
# 4           200        5.0  15915.725466
# 5           200        NaN  16120.662143
# 6           400        3.0  16093.037319
# 7           400        5.0  16142.821863
# 8           400        NaN  16473.812643

# %%
param_grid = {
    "alpha": [0.001, 0.01, 0.1, 1, 10, 50, 100],
    "max_iter": [1000, 5000, 10000]
}

# %%
X = X.ffill().bfill()

# %%
from sklearn.linear_model import Lasso

param_grid = {
    "alpha": [0.001, 0.01, 0.1, 1, 10, 50, 100],
    "max_iter": [1000, 5000, 10000],
}

best_params, best_score, results_df = expanding_window_grid_search(
    Lasso,
    param_grid,
    X,
    y,
    initial_train_size=10,
    horizon=1,
    step=1
)

print("\nBest Parameters (Lasso):", best_params)
print("Best Score:", best_score)
results_df
# Out:
# [GridSearch] Params {'alpha': 0.001, 'max_iter': 1000} → Score = 20931.6176
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.190e+09, tolerance: 1.473e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.906e+09, tolerance: 1.953e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.100e+09, tolerance: 2.376e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.672e+09, tolerance: 2.440e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.049e+09, tolerance: 2.440e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.275e+09, tolerance: 2.453e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.496e+09, tolerance: 2.734e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.754e+09, tolerance: 3.127e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.793e+09, tolerance: 3.473e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.802e+09, tolerance: 3.740e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.858e+09, tolerance: 4.035e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.452e+09, tolerance: 4.416e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.943e+08, tolerance: 4.883e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.712e+09, tolerance: 5.234e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.132e+09, tolerance: 6.257e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.515e+09, tolerance: 6.819e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.403e+09, tolerance: 7.062e+06
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 0.001, 'max_iter': 5000} → Score = 20931.6306
# [GridSearch] Params {'alpha': 0.001, 'max_iter': 10000} → Score = 20931.6306
# [GridSearch] Params {'alpha': 0.01, 'max_iter': 1000} → Score = 20931.6096
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.589e+08, tolerance: 1.953e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.613e+09, tolerance: 2.376e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.551e+09, tolerance: 2.440e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.005e+09, tolerance: 2.440e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.254e+09, tolerance: 2.453e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.481e+09, tolerance: 2.734e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.743e+09, tolerance: 3.127e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.782e+09, tolerance: 3.473e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.781e+09, tolerance: 3.740e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.675e+09, tolerance: 4.035e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.793e+09, tolerance: 4.416e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.131e+07, tolerance: 4.883e+06
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 0.01, 'max_iter': 5000} → Score = 20931.6225
# [GridSearch] Params {'alpha': 0.01, 'max_iter': 10000} → Score = 20931.6225
# [GridSearch] Params {'alpha': 0.1, 'max_iter': 1000} → Score = 20931.5294
# [GridSearch] Params {'alpha': 0.1, 'max_iter': 5000} → Score = 20931.5419
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.250e+09, tolerance: 2.440e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.547e+09, tolerance: 2.440e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.037e+09, tolerance: 2.453e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.332e+09, tolerance: 2.734e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.630e+09, tolerance: 3.127e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.664e+09, tolerance: 3.473e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.565e+09, tolerance: 3.740e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.700e+09, tolerance: 4.035e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.889e+08, tolerance: 4.416e+06
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 0.1, 'max_iter': 10000} → Score = 20931.5419
# [GridSearch] Params {'alpha': 1, 'max_iter': 1000} → Score = 20930.7266
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.620e+09, tolerance: 2.453e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.731e+09, tolerance: 2.734e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.449e+09, tolerance: 3.127e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.425e+09, tolerance: 3.473e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.200e+09, tolerance: 3.740e+06
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 1, 'max_iter': 5000} → Score = 20930.7352
# [GridSearch] Params {'alpha': 1, 'max_iter': 10000} → Score = 20930.7352
# [GridSearch] Params {'alpha': 10, 'max_iter': 1000} → Score = 20922.6686
# [GridSearch] Params {'alpha': 10, 'max_iter': 5000} → Score = 20922.6686
# [GridSearch] Params {'alpha': 10, 'max_iter': 10000} → Score = 20922.6686
# [GridSearch] Params {'alpha': 50, 'max_iter': 1000} → Score = 20886.8171
# [GridSearch] Params {'alpha': 50, 'max_iter': 5000} → Score = 20886.8171
# [GridSearch] Params {'alpha': 50, 'max_iter': 10000} → Score = 20886.8171
# [GridSearch] Params {'alpha': 100, 'max_iter': 1000} → Score = 20842.0017
# [GridSearch] Params {'alpha': 100, 'max_iter': 5000} → Score = 20842.0017
# [GridSearch] Params {'alpha': 100, 'max_iter': 10000} → Score = 20842.0017
#
# Best Parameters (Lasso): {'alpha': np.float64(100.0), 'max_iter': np.float64(1000.0)}
# Best Score: 20842.001703861297
#       alpha  max_iter         score
# 0     0.001      1000  20931.617567
# 1     0.001      5000  20931.630609
# 2     0.001     10000  20931.630609
# 3     0.010      1000  20931.609570
# 4     0.010      5000  20931.622542
# 5     0.010     10000  20931.622542
# 6     0.100      1000  20931.529441
# 7     0.100      5000  20931.541874
# 8     0.100     10000  20931.541874
# 9     1.000      1000  20930.726561
# 10    1.000      5000  20930.735171
# 11    1.000     10000  20930.735171
# 12   10.000      1000  20922.668559
# 13   10.000      5000  20922.668559
# 14   10.000     10000  20922.668559
# 15   50.000      1000  20886.817070
# 16   50.000      5000  20886.817070
# 17   50.000     10000  20886.817070
# 18  100.000      1000  20842.001704
# 19  100.000      5000  20842.001704
# 20  100.000     10000  20842.001704

# %% [markdown]
# # train a lasso with alpha 0.001 and max iter 1000 and save it

# %%
from sklearn.linear_model import Lasso

# Initialize model
lasso = Lasso(alpha=100, max_iter=1000)

# Train model
lasso.fit(X, y)
# Out:
# Lasso(alpha=100)

# %%
import joblib

joblib.dump(lasso, "Lasso_last.joblib")
# Out:
# ['Lasso_last.joblib']

# %%
lasso.predict(X[-1:])
# Out:
# array([215634.32445086])

# %%
X[-1:]
# Out:
#     Total_Lagged  Year  Population_lagged
# 44      216533.0  2024          5223100.0

# %% [markdown]
# # Train Random forest & Save it

# %%
rd = RandomForestRegressor(n_estimators=400, max_depth=None)

rd.fit(X, y)
# Out:
# RandomForestRegressor(n_estimators=400)

# %%
X[-1:]
# Out:
#     Total_Lagged  Year  Population_lagged
# 44      216533.0  2024          5223100.0

# %%
rd.predict(X[-1:])
# Out:
# array([216183.2375])

# %%
joblib.dump(rd, "RandomForest_last.joblib")
# Out:
# ['RandomForest_last.joblib']

# %% [markdown]
# # Tuning a Gradient Boosting Algorithm

# %%
from sklearn.ensemble import GradientBoostingRegressor

param_grid = {
    "n_estimators": [100, 300, 600],          # number of boosting stages
    "learning_rate": [0.01, 0.05, 0.1],       # shrinkage
    "max_depth": [1,2, 3, 4],                   # depth of each tree (via base estimator)
                    # only used when loss="huber" or "quantile"
}

best_params, best_score, results_df = expanding_window_grid_search(
    GradientBoostingRegressor,
    param_grid,
    X,
    y,
    initial_train_size=10,
    horizon=1,
    step=1
)

print("\nBest Parameters (GBR):", best_params)
print("Best Score:", best_score)
results_df
# Out:
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 1} → Score = 25140.8197
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 2} → Score = 19670.8047
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3} → Score = 18375.8039
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 4} → Score = 19119.4060
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 1} → Score = 16147.6991
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 2} → Score = 13877.5262
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 3} → Score = 14970.5281
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 4} → Score = 16269.7008
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 1} → Score = 15024.2094
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 2} → Score = 13691.7078
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3} → Score = 15236.2415
# [GridSearch] Params {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 4} → Score = 15850.6934
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 1} → Score = 17814.8356
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 2} → Score = 14664.0792
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 3} → Score = 14925.7942
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 4} → Score = 15976.6186
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 1} → Score = 14193.3068
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 2} → Score = 13483.0115
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 3} → Score = 14942.9906
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 4} → Score = 16639.7758
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 1} → Score = 13060.9740
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 2} → Score = 13551.1615
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 3} → Score = 15224.1849
# [GridSearch] Params {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 4} → Score = 15824.8315
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.01, 'max_depth': 1} → Score = 15862.2284
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.01, 'max_depth': 2} → Score = 13760.2137
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.01, 'max_depth': 3} → Score = 14908.2799
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.01, 'max_depth': 4} → Score = 16144.4497
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.05, 'max_depth': 1} → Score = 13186.0194
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.05, 'max_depth': 2} → Score = 13539.3901
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.05, 'max_depth': 3} → Score = 15090.9333
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.05, 'max_depth': 4} → Score = 16274.6029
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.1, 'max_depth': 1} → Score = 13085.2048
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.1, 'max_depth': 2} → Score = 13470.9211
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.1, 'max_depth': 3} → Score = 14891.4984
# [GridSearch] Params {'n_estimators': 600, 'learning_rate': 0.1, 'max_depth': 4} → Score = 15988.4217
#
# Best Parameters (GBR): {'n_estimators': np.float64(300.0), 'learning_rate': np.float64(0.1), 'max_depth': np.float64(1.0)}
# Best Score: 13060.974032891352
#     n_estimators  learning_rate  max_depth         score
# 0            100           0.01          1  25140.819700
# 1            100           0.01          2  19670.804727
# 2            100           0.01          3  18375.803882
# 3            100           0.01          4  19119.405986
# 4            100           0.05          1  16147.699092
# 5            100           0.05          2  13877.526249
# 6            100           0.05          3  14970.528058
# 7            100           0.05          4  16269.700802
# 8            100           0.10          1  15024.209401
# 9            100           0.10          2  13691.707809
# 10           100           0.10          3  15236.241457
# 11           100           0.10          4  15850.693382
# 12           300           0.01          1  17814.835613
# 13           300           0.01          2  14664.079209
# 14           300           0.01          3  14925.794237
# 15           300           0.01          4  15976.618590
# 16           300           0.05          1  14193.306797
# 17           300           0.05          2  13483.011474
# 18           300           0.05          3  14942.990606
# 19           300           0.05          4  16639.775766
# 20           300           0.10          1  13060.974033
# 21           300           0.10          2  13551.161480
# 22           300           0.10          3  15224.184850
# 23           300           0.10          4  15824.831459
# 24           600           0.01          1  15862.228365
# 25           600           0.01          2  13760.213697
# 26           600           0.01          3  14908.279925
# 27           600           0.01          4  16144.449662
# 28           600           0.05          1  13186.019441
# 29           600           0.05          2  13539.390131
# 30           600           0.05          3  15090.933254
# 31           600           0.05          4  16274.602907
# 32           600           0.10          1  13085.204833
# 33           600           0.10          2  13470.921131
# 34           600           0.10          3  14891.498358
# 35           600           0.10          4  15988.421728

# %%
import joblib


gbr = GradientBoostingRegressor(
    n_estimators=600,
    learning_rate=0.1,
    max_depth=1,
    random_state=42
)

# Train the model
gbr.fit(X, y)
# Out:
# GradientBoostingRegressor(max_depth=1, n_estimators=600, random_state=42)

# %%
joblib.dump(gbr, "gradient_boosting_regressor.joblib")
# Out:
# ['gradient_boosting_regressor.joblib']

# %% [markdown]
# # Hyperparameter Tuning the Population Model

# %%
target_col = "Population"        # or any column you want to predict
feature_cols = ["Total_Lagged","Year","Population_lagged"]

X = df[feature_cols]
y = df[target_col]

# %%
from sklearn.linear_model import Lasso

param_grid = {
    "alpha": [0.001, 0.01, 0.1, 1, 10, 50, 100],
    "max_iter": [1000, 5000, 10000],
}

best_params, best_score, results_df = expanding_window_grid_search(
    Lasso,
    param_grid,
    X,
    y,
    initial_train_size=10,
    horizon=1,
    step=1
)

print("\nBest Parameters (Lasso):", best_params)
print("Best Score:", best_score)
results_df
# Out:
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+09, tolerance: 3.056e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.097e+09, tolerance: 3.455e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.580e+09, tolerance: 3.871e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.778e+09, tolerance: 4.313e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.909e+09, tolerance: 4.790e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.984e+09, tolerance: 5.282e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.379e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.626e+09, tolerance: 6.290e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.644e+09, tolerance: 6.881e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.883e+09, tolerance: 7.584e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.041e+10, tolerance: 8.428e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.075e+10, tolerance: 9.413e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.078e+10, tolerance: 1.052e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.064e+10, tolerance: 1.174e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.099e+10, tolerance: 1.315e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.212e+10, tolerance: 1.453e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.488e+10, tolerance: 1.587e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.570e+10, tolerance: 1.739e+09
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 0.001, 'max_iter': 1000} → Score = 28869.4840
# [GridSearch] Params {'alpha': 0.001, 'max_iter': 5000} → Score = 28869.1854
# [GridSearch] Params {'alpha': 0.001, 'max_iter': 10000} → Score = 28869.1854
# [GridSearch] Params {'alpha': 0.01, 'max_iter': 1000} → Score = 28869.4769
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.396e+08, tolerance: 3.056e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.090e+09, tolerance: 3.455e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.986e+09, tolerance: 3.871e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.642e+09, tolerance: 4.313e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.876e+09, tolerance: 4.790e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.974e+09, tolerance: 5.282e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.375e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.624e+09, tolerance: 6.290e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.643e+09, tolerance: 6.881e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.882e+09, tolerance: 7.584e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.041e+10, tolerance: 8.428e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.074e+10, tolerance: 9.413e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.073e+10, tolerance: 1.052e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.206e+09, tolerance: 1.174e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.030e+10, tolerance: 1.315e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.240e+09, tolerance: 1.453e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.248e+10, tolerance: 1.587e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.475e+10, tolerance: 1.739e+09
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 0.01, 'max_iter': 5000} → Score = 28869.1784
# [GridSearch] Params {'alpha': 0.01, 'max_iter': 10000} → Score = 28869.1784
# [GridSearch] Params {'alpha': 0.1, 'max_iter': 1000} → Score = 28869.4063
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.395e+08, tolerance: 3.455e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.369e+09, tolerance: 3.871e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.439e+09, tolerance: 4.313e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.555e+09, tolerance: 4.790e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.873e+09, tolerance: 5.282e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.331e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.605e+09, tolerance: 6.290e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.632e+09, tolerance: 6.881e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.873e+09, tolerance: 7.584e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.040e+10, tolerance: 8.428e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.069e+10, tolerance: 9.413e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.025e+10, tolerance: 1.052e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.606e+09, tolerance: 1.315e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.152e+09, tolerance: 1.739e+09
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 0.1, 'max_iter': 5000} → Score = 28869.1088
# [GridSearch] Params {'alpha': 0.1, 'max_iter': 10000} → Score = 28869.1088
# [GridSearch] Params {'alpha': 1, 'max_iter': 1000} → Score = 28868.7096
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.509e+09, tolerance: 4.313e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.120e+09, tolerance: 4.790e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.952e+09, tolerance: 5.282e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.914e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.417e+09, tolerance: 6.290e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.527e+09, tolerance: 6.881e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.784e+09, tolerance: 7.584e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.026e+10, tolerance: 8.428e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.019e+10, tolerance: 9.413e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.809e+09, tolerance: 1.052e+09
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 1, 'max_iter': 5000} → Score = 28868.4120
# [GridSearch] Params {'alpha': 1, 'max_iter': 10000} → Score = 28868.4120
# [GridSearch] Params {'alpha': 10, 'max_iter': 1000} → Score = 28861.7395
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.480e+08, tolerance: 4.790e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.384e+09, tolerance: 5.282e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.928e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.803e+09, tolerance: 6.290e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.568e+09, tolerance: 6.881e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.954e+09, tolerance: 7.584e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.003e+09, tolerance: 8.428e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.685e+09, tolerance: 9.413e+08
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 10, 'max_iter': 5000} → Score = 28861.4440
# [GridSearch] Params {'alpha': 10, 'max_iter': 10000} → Score = 28861.4440
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.796e+09, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.995e+09, tolerance: 6.290e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.673e+09, tolerance: 6.881e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.300e+09, tolerance: 7.584e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.498e+09, tolerance: 8.428e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.968e+09, tolerance: 9.413e+08
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 50, 'max_iter': 1000} → Score = 28830.7231
# [GridSearch] Params {'alpha': 50, 'max_iter': 5000} → Score = 28830.4724
# [GridSearch] Params {'alpha': 50, 'max_iter': 10000} → Score = 28830.4724
# [GridSearch] Params {'alpha': 100, 'max_iter': 1000} → Score = 28791.9774
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.417e+08, tolerance: 5.777e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.183e+09, tolerance: 6.290e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.742e+09, tolerance: 6.881e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.373e+09, tolerance: 7.584e+08
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.400e+09, tolerance: 8.428e+08
#   model = cd_fast.enet_coordinate_descent(
# [GridSearch] Params {'alpha': 100, 'max_iter': 5000} → Score = 28791.7789
# [GridSearch] Params {'alpha': 100, 'max_iter': 10000} → Score = 28791.7789
#
# Best Parameters (Lasso): {'alpha': np.float64(100.0), 'max_iter': np.float64(5000.0)}
# Best Score: 28791.778854599088
#       alpha  max_iter         score
# 0     0.001      1000  28869.484035
# 1     0.001      5000  28869.185399
# 2     0.001     10000  28869.185399
# 3     0.010      1000  28869.476877
# 4     0.010      5000  28869.178433
# 5     0.010     10000  28869.178433
# 6     0.100      1000  28869.406332
# 7     0.100      5000  28869.108751
# 8     0.100     10000  28869.108751
# 9     1.000      1000  28868.709635
# 10    1.000      5000  28868.411985
# 11    1.000     10000  28868.411985
# 12   10.000      1000  28861.739543
# 13   10.000      5000  28861.443953
# 14   10.000     10000  28861.443953
# 15   50.000      1000  28830.723119
# 16   50.000      5000  28830.472423
# 17   50.000     10000  28830.472423
# 18  100.000      1000  28791.977439
# 19  100.000      5000  28791.778855
# 20  100.000     10000  28791.778855

# %%
gbr = GradientBoostingRegressor(
    n_estimators=600,
    learning_rate=0.1,
    max_depth=1,
    random_state=42
)

# %%
lasso_model = Lasso(alpha = 0.001,max_iter = 1000)

# %%
lasso_model.fit(X,y)
# Out:
# C:\Users\hp\miniconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.573e+10, tolerance: 1.896e+09
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.001)

# %%
joblib.dump(lasso_model, "lasso_regressor.joblib")
# Out:
# ['lasso_regressor.joblib']

# %% [markdown]
# # Recursive Model Function

# %%
def recursive_forecast_with_exogenous(
    X_last: pd.DataFrame,
    population_model,
    total_model,
    scaler_X_pop,
    scaler_X_total,
    population_feature_name: str,
    horizon: int = 3
):
    """
    Recursive forecast where Population_lagged is predicted first
    and then used to predict total.

    Parameters
    ----------
    X_last : pd.DataFrame
        Last known row of features (t)
    population_model : trained model
        Model that predicts Population_lagged
    total_model : trained model
        Model that predicts total
    scaler_X_pop : fitted scaler
        Scaler used for population model
    scaler_X_total : fitted scaler
        Scaler used for total model
    population_feature_name : str
        Column name of Population_lagged
    horizon : int
        Number of recursive steps

    Returns
    -------
    pd.DataFrame
        Forecasted Population and Total values
    """

    X_current = X_last.copy()
    forecasts = []

    for step in range(1, horizon + 1):

        # ---- Predict Population_lagged ----
        X_pop_scaled = scaler_X_pop.transform(X_current)
        pop_pred = population_model.predict(X_pop_scaled)[0]

        # Update population feature
        X_current[population_feature_name] = pop_pred

        # ---- Predict total ----
        X_total_scaled = scaler_X_total.transform(X_current)
        total_pred = total_model.predict(X_total_scaled)[0]

        # Store predictions
        forecasts.append({
            "step": step,
            "Population_lagged_pred": pop_pred,
            "total_pred": total_pred
        })

        # ---- Shift lags (if needed) ----
        # Example: Population_lagged_1 → Population_lagged_2
        for col in X_current.columns:
            if "_lag" in col:
                lag_num = int(col.split("_lag")[-1])
                if lag_num > 1:
                    X_current[col.replace(f"_lag{lag_num}", f"_lag{lag_num-1}")] = X_current[col]

        # Set newest lag
        X_current[population_feature_name] = pop_pred

    return pd.DataFrame(forecasts)

# %%
import pandas as pd

def recursive_forecast_with_exogenous(
    X_last: pd.DataFrame,
    population_model,
    total_model,
    population_feature_name: str,
    horizon: int = 3
):
    """
    Recursive forecast where Population_lagged is predicted first
    and then used to predict total.

    Parameters
    ----------
    X_last : pd.DataFrame
        Last known row of features (t)
    population_model : trained model
        Model that predicts Population_lagged
    total_model : trained model
        Model that predicts total
    population_feature_name : str
        Column name of Population_lagged
    horizon : int
        Number of recursive steps

    Returns
    -------
    pd.DataFrame
        Forecasted Population and Total values
    """

    X_current = X_last.copy()
    forecasts = []

    for step in range(1, horizon + 1):

        # ---- Predict Population_lagged ----
        pop_pred = population_model.predict(X_current)[0]

        # Update population feature
        X_current[population_feature_name] = pop_pred

        # ---- Predict total ----
        total_pred = total_model.predict(X_current)[0]

        # Store predictions
        forecasts.append({
            "step": step,
            "Population_lagged_pred": pop_pred,
            "total_pred": total_pred
        })

        # ---- Shift lagged features ----
        for col in X_current.columns:
            if "_lag" in col:
                lag_num = int(col.split("_lag")[-1])
                if lag_num > 1:
                    X_current[col.replace(
                        f"_lag{lag_num}", f"_lag{lag_num-1}"
                    )] = X_current[col]

        # Set newest lag explicitly
        X_current[population_feature_name] = pop_pred

    return pd.DataFrame(forecasts)

# %%
predictions = recursive_forecast_with_exogenous(X[:-1], lasso_model, gbr, "Population_lagged")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 predictions = recursive_forecast_with_exogenous(X[:-1], lasso_model, gbr, "Population_lagged")
#
# Cell In[98], line 57, in recursive_forecast_with_exogenous(X_last, population_model, total_model, population_feature_name, horizon)
#      55 for col in X_current.columns:
#      56     if "_lag" in col:
# ---> 57         lag_num = int(col.split("_lag")[-1])
#      58         if lag_num > 1:
#      59             X_current[col.replace(
#      60                 f"_lag{lag_num}", f"_lag{lag_num-1}"
#      61             )] = X_current[col]
#
# ValueError: invalid literal for int() with base 10: 'ged'

# %% [markdown]
# # Fix the fockn error
