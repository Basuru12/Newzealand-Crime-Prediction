# %%
import pandas as pd

# %%
population_data = pd.read_csv("newzeland population.csv")

# %%
population_data
# Out:
#     Year  Population
# 30  1980     3673400
# 31  1981     3620000
# 32  1982     3572200
# 33  1983     3531700
# 34  1984     3495100
# 35  1985     3329800
# 36  1986     3299200
# 37  1987     3283400
# 38  1988     3274400
# 39  1989     3246300
# 40  1990     3247100
# 41  1991     3227100
# 42  1992     3199300
# 43  1993     3156100
# 44  1994     3124900
# 45  1995     3112900
# 46  1996     3109000
# 47  1997     3121200
# 48  1998     3120200
# 49  1999     3110500
# 50  2000     3083100
# 51  2001     3023700
# 52  2002     2961300
# 53  2003     2903900
# 54  2004     2853000
# 55  2005     2810700
# 56  2006     2772800
# 57  2007     2748100
# 58  2008     2724100
# 59  2009     2675900
# 60  2010     2628400
# 61  2011     2585400
# 62  2012     2531800
# 63  2013     2482000
# 64  2014     2419700
# 65  2015     2371800
# 66  2016     2335010
# 67  2017     2286559
# 68  2018     2235321
# 69  2019     2186348
# 70  2020     2140976
# 71  2021     2096332
# ...

# %%
population_data['Year'] = population_data['Year'].iloc[::-1].values

# %%
population_data["Year"] = population_data["Year"].astype(int)

# %%
population_data = population_data[ population_data["Year"] > 1979 ]

# %%
df = pd.read_csv("cleaned_dataset.csv")

# %%
df
# Out:
#     Homicide  Assault  Sexual offences  Harm or endanger persons  \
# 0        353     7208             1401                      2176
# 1        366     7933             1092                      2299
# 2        329     7760             1298                      2231
# 3        407     8741             1449                      2693
# 4        406     9349             1682                      2651
# 5        447     9671             1816                      2901
# 6        464    10244             1917                      3143
# 7        485    11476             2180                      3204
# 8        529    12469             2440                      3346
# 9        603    11567             2442                      3265
# 10       552    11739             2986                      3773
# 11       489    12581             3671                      3797
# 12       439    14432             4813                      4394
# ...
