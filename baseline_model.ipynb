# %% [markdown]
# # Naive Forcast Model

# %%
import pandas as pd

# %%
df = pd.read_csv('New_csv.csv')

# %%
df.dropna(inplace = True)

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(df["Crime_Index"], df["Crime_Index_Lagged"])
print("MAE:", mae)
# Out:
# MAE: 0.3684260840011064
